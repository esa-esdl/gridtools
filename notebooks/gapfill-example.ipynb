# %%
# %matplotlib inline
import gridtools.gapfilling as gtg
import numpy as np
from PIL import Image

# %%
im = Image.open("houses-with-gaps.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1322x800 at 0x262F5A72EF0>

# %%
im_data = np.asarray(im, dtype=np.float32)
data = im_data[:,:,0]
alpha = im_data[:,:,3]
data[np.where(alpha < 255)] = np.nan

# %%
data_filled = gtg.fillgaps_lowpass_2d(data)
Image.fromarray(np.uint8(data_filled))
# Out:
# <PIL.Image.Image image mode=L size=1322x800 at 0x262F7EC0630>

# %%
data_filled = gtg.fillgaps_multiscale_2d(data)
Image.fromarray(np.uint8(data_filled))
# Out:
# <PIL.Image.Image image mode=L size=1322x800 at 0x262F84AA208>
