# %%
# %matplotlib inline
import gridtools.resampling as gtr
import numpy as np
from PIL import Image

# %%
im = Image.open("houses.png")

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1322x800 at 0x2EE69426668>

# %%
a = np.asarray(im, dtype=np.float32)
a_low = gtr.resample2d(a, a.shape[-1] // 20, a.shape[-2] // 20)
im_low = Image.fromarray(np.uint8(a_low))

# %%
im_low
# Out:
# <PIL.Image.Image image mode=L size=66x40 at 0x2EE6C05C358>

# %%
a_hi = gtr.resample2d(a_low, a.shape[-1], a.shape[-2], us_method=gtr.US_NEAREST)
im_hi = Image.fromarray(np.uint8(a_hi))

# %%
im_hi
# Out:
# <PIL.Image.Image image mode=L size=1322x800 at 0x2EE6C057518>
